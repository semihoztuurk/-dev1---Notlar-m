# %%
import numpy as np
import matplotlib.pyplot as mpl

# %%
maasListesi = numpy.random.normal(4000,500,1000)
numpy.mean(maasListesi)
# Out:
# 4018.175060389655

# %%
mpl.hist(maasListesi,50)
mpl.show()
